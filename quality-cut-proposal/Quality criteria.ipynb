# %%
# %matplotlib inline
import matplotlib.pyplot as pl
from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
import seaborn as sns

from tqdm import tqdm
import numpy as np

# %% [markdown]
# ## What is the mean expected transit frequency as a function of the channel?

# %%
import pandas as pd
transits = pd.read_hdf('../sandbox/all-tce-transits.h5', key='transits')
print('Loaded {} transits'.format(len(transits)))
# Out:
# Loaded 16220518 transits

# %%
transits
# Out:
#              kepid           tce  tce_max_mult_ev  tce_period  tce_plnt_num  \
# 0          2304168  002304168-02           12.220  431.719000             2
# 1          2304168  002304168-02           12.220  431.719000             2
# 2          2304168  002304168-02           12.220  431.719000             2
# 3          2304168  002304168-02           12.220  431.719000             2
# 4          2304235  002304235-01           17.510    0.570607             1
# 5          2304235  002304235-01           17.510    0.570607             1
# 6          2304235  002304235-01           17.510    0.570607             1
# 7          2304235  002304235-01           17.510    0.570607             1
# 8          2304235  002304235-01           17.510    0.570607             1
# 9          2304235  002304235-01           17.510    0.570607             1
# 10         2304235  002304235-01           17.510    0.570607             1
# ...
